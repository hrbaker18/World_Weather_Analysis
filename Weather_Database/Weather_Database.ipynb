# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-95.00, 95.00, 2000)
lngs = np.random.uniform(-180.00, 180.00, 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 755

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                              "Country": city_country,
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Current Description": city_weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | dikson
# Processing Record 2 of Set 1 | buraydah
# Processing Record 3 of Set 1 | saint-philippe
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | shingu
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | barrow
# Processing Record 8 of Set 1 | genhe
# Processing Record 9 of Set 1 | upernavik
# Processing Record 10 of Set 1 | puerto ayora
# Processing Record 11 of Set 1 | one hundred mile house
# City not found. Skipping...
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 1 | thunder bay
# Processing Record 17 of Set 1 | aljezur
# Processing Record 18 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | port alfred
# Processing Record 21 of Set 1 | hofn
# Processing Record 22 of Set 1 | najran
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 1 | nikolskoye
# Processing Record 26 of Set 1 | cao bang
# Processing Record 27 of Set 1 | port elizabeth
# Processing Record 28 of Set 1 | san angelo
# Processing Record 29 of Set 1 | kahului
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | te anau
# Processing Record 32 of Set 1 | salalah
# Processing Record 33 of Set 1 | chuy
# Processing Record 34 of Set 1 | waingapu
# Processing Record 35 of Set 1 | maceio
# Processing Record 36 of Set 1 | cidreira
# Processing Record 37 of Set 1 | santiago de chuco
# Processing Record 38 of Set 1 | huarmey
# Processing Record 39 of Set 1 | mataura
# Processing Record 40 of Set 1 | clyde river
# Processing Record 41 of Set 1 | iskateley
# Processing Record 42 of Set 1 | novy hrozenkov
# Processing Record 43 of Set 1 | pevek
# Processing Record 44 of Set 1 | nanortalik
# Processing Record 45 of Set 1 | hobart
# Processing Record 46 of Set 1 | laguna
# Processing Record 47 of Set 1 | sao filipe
# Processing Record 48 of Set 1 | sitka
# Processing Record 49 of Set 1 | waitati
# Processing Record 50 of Set 1 | klaksvik
# Processing Record 1 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 2 | dongling
# Processing Record 3 of Set 2 | agadez
# Processing Record 4 of Set 2 | ugoofaaru
# Processing Record 5 of Set 2 | les cayes
# Processing Record 6 of Set 2 | arraial do cabo
# Processing Record 7 of Set 2 | tura
# Processing Record 8 of Set 2 | huntsville
# Processing Record 9 of Set 2 | havre-saint-pierre
# Processing Record 10 of Set 2 | marzuq
# Processing Record 11 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 2 | shepsi
# Processing Record 13 of Set 2 | la palma
# Processing Record 14 of Set 2 | avarua
# Processing Record 15 of Set 2 | bethel
# Processing Record 16 of Set 2 | faya
# Processing Record 17 of Set 2 | bambous virieux
# Processing Record 18 of Set 2 | timmins
# Processing Record 19 of Set 2 | san quintin
# Processing Record 20 of Set 2 | yellowknife
# Processing Record 21 of Set 2 | shimoda
# Processing Record 22 of Set 2 | tendukheda
# Processing Record 23 of Set 2 | marfino
# Processing Record 24 of Set 2 | yulara
# Processing Record 25 of Set 2 | atuona
# Processing Record 26 of Set 2 | vao
# Processing Record 27 of Set 2 | tiksi
# Processing Record 28 of Set 2 | honiara
# Processing Record 29 of Set 2 | san lorenzo
# Processing Record 30 of Set 2 | cape town
# Processing Record 31 of Set 2 | willowmore
# Processing Record 32 of Set 2 | haines junction
# Processing Record 33 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 34 of Set 2 | vaini
# Processing Record 35 of Set 2 | opuwo
# Processing Record 36 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 37 of Set 2 | esperance
# Processing Record 38 of Set 2 | fortuna
# Processing Record 39 of Set 2 | bocaranga
# City not found. Skipping...
# Processing Record 40 of Set 2 | xinqing
# Processing Record 41 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 2 | neryungri
# Processing Record 43 of Set 2 | torbay
# Processing Record 44 of Set 2 | morondava
# Processing Record 45 of Set 2 | jalu
# Processing Record 46 of Set 2 | qaanaaq
# Processing Record 47 of Set 2 | provideniya
# Processing Record 48 of Set 2 | coquimbo
# Processing Record 49 of Set 2 | saskylakh
# Processing Record 50 of Set 2 | inta
# Processing Record 1 of Set 3 | hithadhoo
# Processing Record 2 of Set 3 | mahebourg
# Processing Record 3 of Set 3 | luderitz
# Processing Record 4 of Set 3 | kapaa
# Processing Record 5 of Set 3 | ostrovnoy
# Processing Record 6 of Set 3 | ginir
# Processing Record 7 of Set 3 | sumenep
# Processing Record 8 of Set 3 | longyearbyen
# Processing Record 9 of Set 3 | jamestown
# Processing Record 10 of Set 3 | pinheiro machado
# Processing Record 11 of Set 3 | hilo
# Processing Record 12 of Set 3 | los llanos de aridane
# Processing Record 13 of Set 3 | georgetown
# Processing Record 14 of Set 3 | butaritari
# Processing Record 15 of Set 3 | hanna
# Processing Record 16 of Set 3 | isangel
# Processing Record 17 of Set 3 | bredasdorp
# Processing Record 18 of Set 3 | khromtau
# Processing Record 19 of Set 3 | katsuura
# Processing Record 20 of Set 3 | praia da vitoria
# Processing Record 21 of Set 3 | la reforma
# Processing Record 22 of Set 3 | sola
# Processing Record 23 of Set 3 | portland
# Processing Record 24 of Set 3 | pacific grove
# Processing Record 25 of Set 3 | grand gaube
# Processing Record 26 of Set 3 | norman wells
# Processing Record 27 of Set 3 | birjand
# Processing Record 28 of Set 3 | saint anthony
# Processing Record 29 of Set 3 | san ignacio
# Processing Record 30 of Set 3 | dryden
# Processing Record 31 of Set 3 | vardo
# Processing Record 32 of Set 3 | mitsamiouli
# Processing Record 33 of Set 3 | teya
# Processing Record 34 of Set 3 | tasiilaq
# Processing Record 35 of Set 3 | saldanha
# Processing Record 36 of Set 3 | birin
# Processing Record 37 of Set 3 | nuuk
# Processing Record 38 of Set 3 | cody
# Processing Record 39 of Set 3 | lavrentiya
# Processing Record 40 of Set 3 | margate
# Processing Record 41 of Set 3 | east london
# Processing Record 42 of Set 3 | pokaran
# Processing Record 43 of Set 3 | leningradskiy
# Processing Record 44 of Set 3 | srivardhan
# Processing Record 45 of Set 3 | ushtobe
# Processing Record 46 of Set 3 | vaitape
# Processing Record 47 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 3 | chokurdakh
# Processing Record 49 of Set 3 | san jose
# Processing Record 50 of Set 3 | dwarahat
# Processing Record 1 of Set 4 | sur
# Processing Record 2 of Set 4 | san cristobal
# Processing Record 3 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 4 | pangnirtung
# Processing Record 5 of Set 4 | maridi
# Processing Record 6 of Set 4 | cabo san lucas
# Processing Record 7 of Set 4 | tabuk
# Processing Record 8 of Set 4 | port hawkesbury
# Processing Record 9 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 4 | itarema
# Processing Record 11 of Set 4 | ouadda
# Processing Record 12 of Set 4 | ornskoldsvik
# Processing Record 13 of Set 4 | andilamena
# Processing Record 14 of Set 4 | husavik
# Processing Record 15 of Set 4 | nakuru
# Processing Record 16 of Set 4 | lagoa
# Processing Record 17 of Set 4 | porto novo
# Processing Record 18 of Set 4 | hanstholm
# Processing Record 19 of Set 4 | namibe
# Processing Record 20 of Set 4 | pavlivka
# Processing Record 21 of Set 4 | skjervoy
# Processing Record 22 of Set 4 | kendal
# Processing Record 23 of Set 4 | nantucket
# Processing Record 24 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 25 of Set 4 | zaysan
# Processing Record 26 of Set 4 | bacolod
# Processing Record 27 of Set 4 | hobyo
# Processing Record 28 of Set 4 | gazojak
# Processing Record 29 of Set 4 | bealanana
# Processing Record 30 of Set 4 | tuktoyaktuk
# Processing Record 31 of Set 4 | guerrero negro
# Processing Record 32 of Set 4 | honningsvag
# Processing Record 33 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 34 of Set 4 | cherskiy
# Processing Record 35 of Set 4 | castro
# Processing Record 36 of Set 4 | tuatapere
# Processing Record 37 of Set 4 | celestun
# Processing Record 38 of Set 4 | hamilton
# Processing Record 39 of Set 4 | college
# Processing Record 40 of Set 4 | aklavik
# Processing Record 41 of Set 4 | kavieng
# Processing Record 42 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 43 of Set 4 | lagunas
# Processing Record 44 of Set 4 | ayan
# Processing Record 45 of Set 4 | machico
# Processing Record 46 of Set 4 | nome
# Processing Record 47 of Set 4 | blackfoot
# Processing Record 48 of Set 4 | leeton
# Processing Record 49 of Set 4 | thompson
# Processing Record 50 of Set 4 | chato
# Processing Record 1 of Set 5 | rio grande
# Processing Record 2 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 5 | quatre cocos
# Processing Record 4 of Set 5 | khatanga
# Processing Record 5 of Set 5 | wenling
# Processing Record 6 of Set 5 | iqaluit
# Processing Record 7 of Set 5 | artigas
# Processing Record 8 of Set 5 | flin flon
# Processing Record 9 of Set 5 | ponta do sol
# Processing Record 10 of Set 5 | kargopol
# Processing Record 11 of Set 5 | pisco
# Processing Record 12 of Set 5 | saint-augustin
# Processing Record 13 of Set 5 | pochutla
# Processing Record 14 of Set 5 | solnechnyy
# Processing Record 15 of Set 5 | thinadhoo
# Processing Record 16 of Set 5 | campo maior
# Processing Record 17 of Set 5 | naze
# Processing Record 18 of Set 5 | faanui
# Processing Record 19 of Set 5 | hami
# Processing Record 20 of Set 5 | labis
# Processing Record 21 of Set 5 | vilani
# Processing Record 22 of Set 5 | avera
# Processing Record 23 of Set 5 | sorkjosen
# Processing Record 24 of Set 5 | udachnyy
# Processing Record 25 of Set 5 | puerto leguizamo
# Processing Record 26 of Set 5 | saint-jean-de-maurienne
# Processing Record 27 of Set 5 | miranda
# Processing Record 28 of Set 5 | kentau
# Processing Record 29 of Set 5 | lorengau
# Processing Record 30 of Set 5 | san patricio
# Processing Record 31 of Set 5 | samarai
# Processing Record 32 of Set 5 | kalaiya
# Processing Record 33 of Set 5 | doha
# Processing Record 34 of Set 5 | constitucion
# Processing Record 35 of Set 5 | souillac
# Processing Record 36 of Set 5 | nabire
# Processing Record 37 of Set 5 | umm kaddadah
# Processing Record 38 of Set 5 | macrohon
# Processing Record 39 of Set 5 | carnarvon
# Processing Record 40 of Set 5 | nelson bay
# Processing Record 41 of Set 5 | tokoroa
# Processing Record 42 of Set 5 | la ronge
# Processing Record 43 of Set 5 | brownwood
# Processing Record 44 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 45 of Set 5 | henties bay
# Processing Record 46 of Set 5 | berlevag
# Processing Record 47 of Set 5 | bandarbeyla
# Processing Record 48 of Set 5 | avallon
# Processing Record 49 of Set 5 | bay roberts
# Processing Record 50 of Set 5 | ajaccio
# Processing Record 1 of Set 6 | adrar
# Processing Record 2 of Set 6 | lebu
# Processing Record 3 of Set 6 | matoury
# Processing Record 4 of Set 6 | wasilla
# Processing Record 5 of Set 6 | nyurba
# Processing Record 6 of Set 6 | new norfolk
# Processing Record 7 of Set 6 | leh
# Processing Record 8 of Set 6 | bella vista
# Processing Record 9 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 10 of Set 6 | amarpur
# Processing Record 11 of Set 6 | rawson
# Processing Record 12 of Set 6 | geraldton
# Processing Record 13 of Set 6 | gat
# Processing Record 14 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 6 | kulhudhuffushi
# Processing Record 16 of Set 6 | sechelt
# Processing Record 17 of Set 6 | emerald
# Processing Record 18 of Set 6 | kushima
# Processing Record 19 of Set 6 | sorong
# Processing Record 20 of Set 6 | teeli
# Processing Record 21 of Set 6 | bhikangaon
# Processing Record 22 of Set 6 | camacha
# Processing Record 23 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 6 | charters towers
# Processing Record 25 of Set 6 | itaqui
# Processing Record 26 of Set 6 | padang
# Processing Record 27 of Set 6 | kyakhta
# Processing Record 28 of Set 6 | port hardy
# Processing Record 29 of Set 6 | orlik
# Processing Record 30 of Set 6 | bayevo
# Processing Record 31 of Set 6 | riyadh
# Processing Record 32 of Set 6 | kaitangata
# Processing Record 33 of Set 6 | paragominas
# Processing Record 34 of Set 6 | sokoto
# Processing Record 35 of Set 6 | amapa
# Processing Record 36 of Set 6 | karratha
# Processing Record 37 of Set 6 | beloha
# Processing Record 38 of Set 6 | robertson
# Processing Record 39 of Set 6 | ribeira grande
# Processing Record 40 of Set 6 | florianopolis
# Processing Record 41 of Set 6 | codrington
# Processing Record 42 of Set 6 | pemba
# Processing Record 43 of Set 6 | belaya gora
# Processing Record 44 of Set 6 | hasaki
# Processing Record 45 of Set 6 | severo-kurilsk
# Processing Record 46 of Set 6 | niquelandia
# Processing Record 47 of Set 6 | kachikau
# City not found. Skipping...
# Processing Record 48 of Set 6 | baykit
# Processing Record 49 of Set 6 | safaga
# Processing Record 50 of Set 6 | imbituba
# Processing Record 1 of Set 7 | tefe
# Processing Record 2 of Set 7 | sao felix do xingu
# Processing Record 3 of Set 7 | vanimo
# Processing Record 4 of Set 7 | sabha
# Processing Record 5 of Set 7 | pashiya
# Processing Record 6 of Set 7 | kajaani
# Processing Record 7 of Set 7 | kurchum
# Processing Record 8 of Set 7 | sao jose da coroa grande
# Processing Record 9 of Set 7 | coahuayana
# Processing Record 10 of Set 7 | aswan
# Processing Record 11 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 7 | pangkalanbuun
# Processing Record 13 of Set 7 | carmen
# Processing Record 14 of Set 7 | mar del plata
# Processing Record 15 of Set 7 | asekeyevo
# Processing Record 16 of Set 7 | geresk
# City not found. Skipping...
# Processing Record 17 of Set 7 | tongchuan
# Processing Record 18 of Set 7 | champerico
# Processing Record 19 of Set 7 | bahir dar
# Processing Record 20 of Set 7 | bengkulu
# Processing Record 21 of Set 7 | mount gambier
# Processing Record 22 of Set 7 | zhezkazgan
# Processing Record 23 of Set 7 | hukuntsi
# Processing Record 24 of Set 7 | kenora
# Processing Record 25 of Set 7 | sakakah
# Processing Record 26 of Set 7 | toguchin
# Processing Record 27 of Set 7 | muros
# Processing Record 28 of Set 7 | coihaique
# Processing Record 29 of Set 7 | derzhavinsk
# Processing Record 30 of Set 7 | brejo da madre de deus
# Processing Record 31 of Set 7 | plouzane
# Processing Record 32 of Set 7 | nouadhibou
# Processing Record 33 of Set 7 | carutapera
# Processing Record 34 of Set 7 | sol-iletsk
# Processing Record 35 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 36 of Set 7 | srednekolymsk
# Processing Record 37 of Set 7 | gawler
# Processing Record 38 of Set 7 | dunmore town
# Processing Record 39 of Set 7 | tucuman
# Processing Record 40 of Set 7 | saint-pierre
# Processing Record 41 of Set 7 | taganak
# Processing Record 42 of Set 7 | port blair
# Processing Record 43 of Set 7 | ancud
# Processing Record 44 of Set 7 | elmina
# Processing Record 45 of Set 7 | banda aceh
# Processing Record 46 of Set 7 | akhisar
# Processing Record 47 of Set 7 | tiarei
# Processing Record 48 of Set 7 | marienburg
# Processing Record 49 of Set 7 | marawi
# Processing Record 50 of Set 7 | rantepao
# Processing Record 1 of Set 8 | kupang
# Processing Record 2 of Set 8 | victoria
# Processing Record 3 of Set 8 | kodiak
# Processing Record 4 of Set 8 | tayu
# Processing Record 5 of Set 8 | asfi
# Processing Record 6 of Set 8 | gejiu
# Processing Record 7 of Set 8 | matadi
# Processing Record 8 of Set 8 | ucluelet
# Processing Record 9 of Set 8 | yunyang
# Processing Record 10 of Set 8 | tawang
# Processing Record 11 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 8 | whitehorse
# Processing Record 13 of Set 8 | taltal
# Processing Record 14 of Set 8 | richards bay
# Processing Record 15 of Set 8 | afmadu
# City not found. Skipping...
# Processing Record 16 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 17 of Set 8 | tautira
# Processing Record 18 of Set 8 | mount isa
# Processing Record 19 of Set 8 | wilkie
# Processing Record 20 of Set 8 | seoul
# Processing Record 21 of Set 8 | tingo maria
# Processing Record 22 of Set 8 | alofi
# Processing Record 23 of Set 8 | turayf
# Processing Record 24 of Set 8 | powell river
# Processing Record 25 of Set 8 | karauzyak
# City not found. Skipping...
# Processing Record 26 of Set 8 | balaipungut
# Processing Record 27 of Set 8 | narsaq
# Processing Record 28 of Set 8 | shubarshi
# Processing Record 29 of Set 8 | mandalgovi
# Processing Record 30 of Set 8 | manaus
# Processing Record 31 of Set 8 | mayumba
# Processing Record 32 of Set 8 | marsh harbour
# Processing Record 33 of Set 8 | poronaysk
# Processing Record 34 of Set 8 | khilok
# Processing Record 35 of Set 8 | amga
# Processing Record 36 of Set 8 | jinka
# Processing Record 37 of Set 8 | yarmouth
# Processing Record 38 of Set 8 | cairns
# Processing Record 39 of Set 8 | tommot
# Processing Record 40 of Set 8 | russell
# Processing Record 41 of Set 8 | kwinana
# Processing Record 42 of Set 8 | belomorsk
# Processing Record 43 of Set 8 | vila velha
# Processing Record 44 of Set 8 | lucapa
# Processing Record 45 of Set 8 | sao joao da barra
# Processing Record 46 of Set 8 | alihe
# Processing Record 47 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 8 | meulaboh
# Processing Record 49 of Set 8 | yumen
# Processing Record 50 of Set 8 | de land
# Processing Record 1 of Set 9 | salihorsk
# Processing Record 2 of Set 9 | straja
# Processing Record 3 of Set 9 | beringovskiy
# Processing Record 4 of Set 9 | kristiansund
# Processing Record 5 of Set 9 | alekseyevka
# Processing Record 6 of Set 9 | broken hill
# Processing Record 7 of Set 9 | namie
# Processing Record 8 of Set 9 | mareeba
# Processing Record 9 of Set 9 | jumla
# Processing Record 10 of Set 9 | manokwari
# Processing Record 11 of Set 9 | toora-khem
# Processing Record 12 of Set 9 | buin
# Processing Record 13 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 14 of Set 9 | airai
# Processing Record 15 of Set 9 | kruisfontein
# Processing Record 16 of Set 9 | coihueco
# Processing Record 17 of Set 9 | bonfim
# Processing Record 18 of Set 9 | biltine
# Processing Record 19 of Set 9 | kaura namoda
# Processing Record 20 of Set 9 | kumluca
# Processing Record 21 of Set 9 | mogadishu
# Processing Record 22 of Set 9 | huadian
# Processing Record 23 of Set 9 | champasak
# Processing Record 24 of Set 9 | torres
# Processing Record 25 of Set 9 | ziro
# Processing Record 26 of Set 9 | tshela
# Processing Record 27 of Set 9 | vilhena
# Processing Record 28 of Set 9 | skegness
# Processing Record 29 of Set 9 | simao
# Processing Record 30 of Set 9 | kisoro
# Processing Record 31 of Set 9 | goderich
# Processing Record 32 of Set 9 | batagay
# Processing Record 33 of Set 9 | salinopolis
# Processing Record 34 of Set 9 | asyut
# Processing Record 35 of Set 9 | dokri
# Processing Record 36 of Set 9 | teguise
# Processing Record 37 of Set 9 | bayji
# Processing Record 38 of Set 9 | saint simons
# Processing Record 39 of Set 9 | severo-yeniseyskiy
# Processing Record 40 of Set 9 | ruteng
# Processing Record 41 of Set 9 | borodino
# Processing Record 42 of Set 9 | cochrane
# Processing Record 43 of Set 9 | slave lake
# Processing Record 44 of Set 9 | tanete
# Processing Record 45 of Set 9 | xichang
# Processing Record 46 of Set 9 | trincomalee
# Processing Record 47 of Set 9 | grindavik
# Processing Record 48 of Set 9 | belmopan
# Processing Record 49 of Set 9 | gunjur
# Processing Record 50 of Set 9 | kontagora
# Processing Record 1 of Set 10 | the pas
# Processing Record 2 of Set 10 | nata
# Processing Record 3 of Set 10 | west lorne
# Processing Record 4 of Set 10 | shilovo
# Processing Record 5 of Set 10 | samana
# Processing Record 6 of Set 10 | urucara
# Processing Record 7 of Set 10 | awjilah
# Processing Record 8 of Set 10 | duz
# City not found. Skipping...
# Processing Record 9 of Set 10 | zhuhai
# Processing Record 10 of Set 10 | ulaangom
# Processing Record 11 of Set 10 | zyryanka
# Processing Record 12 of Set 10 | hambantota
# Processing Record 13 of Set 10 | asgabat
# Processing Record 14 of Set 10 | moose factory
# Processing Record 15 of Set 10 | xingyi
# Processing Record 16 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 17 of Set 10 | fairbanks
# Processing Record 18 of Set 10 | fuchu
# Processing Record 19 of Set 10 | pocone
# Processing Record 20 of Set 10 | hervey bay
# Processing Record 21 of Set 10 | wagar
# Processing Record 22 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 10 | neiafu
# Processing Record 24 of Set 10 | port lincoln
# Processing Record 25 of Set 10 | mao
# Processing Record 26 of Set 10 | poum
# Processing Record 27 of Set 10 | svarstad
# Processing Record 28 of Set 10 | labuhan
# Processing Record 29 of Set 10 | kurtamysh
# Processing Record 30 of Set 10 | bolshaya rechka
# Processing Record 31 of Set 10 | rocha
# Processing Record 32 of Set 10 | kaniama
# Processing Record 33 of Set 10 | ferzikovo
# Processing Record 34 of Set 10 | mbaiki
# Processing Record 35 of Set 10 | kayes
# Processing Record 36 of Set 10 | muzhi
# Processing Record 37 of Set 10 | ruwi
# Processing Record 38 of Set 10 | verkhoyansk
# Processing Record 39 of Set 10 | belyy yar
# Processing Record 40 of Set 10 | biak
# Processing Record 41 of Set 10 | linhares
# Processing Record 42 of Set 10 | am timan
# Processing Record 43 of Set 10 | jujuy
# City not found. Skipping...
# Processing Record 44 of Set 10 | marstal
# Processing Record 45 of Set 10 | catuday
# Processing Record 46 of Set 10 | nagorsk
# Processing Record 47 of Set 10 | dalnerechensk
# Processing Record 48 of Set 10 | cap malheureux
# Processing Record 49 of Set 10 | huambo
# Processing Record 50 of Set 10 | aigle
# Processing Record 1 of Set 11 | sungairaya
# Processing Record 2 of Set 11 | heihe
# Processing Record 3 of Set 11 | jinotega
# Processing Record 4 of Set 11 | merauke
# Processing Record 5 of Set 11 | eureka
# Processing Record 6 of Set 11 | newton
# Processing Record 7 of Set 11 | terrace
# Processing Record 8 of Set 11 | launceston
# Processing Record 9 of Set 11 | bom jardim
# Processing Record 10 of Set 11 | puro
# Processing Record 11 of Set 11 | saurimo
# Processing Record 12 of Set 11 | lompoc
# Processing Record 13 of Set 11 | akhaldaba
# Processing Record 14 of Set 11 | shiraz
# Processing Record 15 of Set 11 | lishui
# Processing Record 16 of Set 11 | tolaga bay
# Processing Record 17 of Set 11 | hua hin
# Processing Record 18 of Set 11 | talnakh
# Processing Record 19 of Set 11 | san policarpo
# Processing Record 20 of Set 11 | marystown
# Processing Record 21 of Set 11 | valparaiso
# Processing Record 22 of Set 11 | linden
# Processing Record 23 of Set 11 | craig
# Processing Record 24 of Set 11 | gorom-gorom
# Processing Record 25 of Set 11 | okha
# Processing Record 26 of Set 11 | nanakuli
# Processing Record 27 of Set 11 | batemans bay
# Processing Record 28 of Set 11 | churapcha
# Processing Record 29 of Set 11 | north bend
# Processing Record 30 of Set 11 | lubumbashi
# Processing Record 31 of Set 11 | victor harbor
# Processing Record 32 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 34 of Set 11 | buala
# Processing Record 35 of Set 11 | vikhorevka
# Processing Record 36 of Set 11 | opochka
# Processing Record 37 of Set 11 | sortavala
# Processing Record 38 of Set 11 | shaoyang
# Processing Record 39 of Set 11 | bajo baudo
# City not found. Skipping...
# Processing Record 40 of Set 11 | nador
# Processing Record 41 of Set 11 | belluno
# Processing Record 42 of Set 11 | storslett
# Processing Record 43 of Set 11 | north platte
# Processing Record 44 of Set 11 | olafsvik
# Processing Record 45 of Set 11 | prince rupert
# Processing Record 46 of Set 11 | caceres
# Processing Record 47 of Set 11 | san pedro
# Processing Record 48 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 49 of Set 11 | chervone
# Processing Record 50 of Set 11 | kudirkos naumiestis
# Processing Record 1 of Set 12 | ilulissat
# Processing Record 2 of Set 12 | wamba
# Processing Record 3 of Set 12 | kununurra
# Processing Record 4 of Set 12 | winsum
# Processing Record 5 of Set 12 | calama
# Processing Record 6 of Set 12 | tabas
# Processing Record 7 of Set 12 | yar-sale
# Processing Record 8 of Set 12 | sao borja
# Processing Record 9 of Set 12 | ambilobe
# Processing Record 10 of Set 12 | sagua la grande
# Processing Record 11 of Set 12 | mehamn
# Processing Record 12 of Set 12 | lagos
# Processing Record 13 of Set 12 | tilichiki
# Processing Record 14 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 15 of Set 12 | mae hong son
# Processing Record 16 of Set 12 | omsukchan
# Processing Record 17 of Set 12 | suileng
# Processing Record 18 of Set 12 | burgeo
# Processing Record 19 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 20 of Set 12 | kudahuvadhoo
# Processing Record 21 of Set 12 | awbari
# Processing Record 22 of Set 12 | sabang
# Processing Record 23 of Set 12 | bathsheba
# Processing Record 24 of Set 12 | chardara
# Processing Record 25 of Set 12 | abbeyfeale
# Processing Record 26 of Set 12 | gewane
# Processing Record 27 of Set 12 | digby
# Processing Record 28 of Set 12 | ketchikan
# Processing Record 29 of Set 12 | burica
# City not found. Skipping...
# Processing Record 30 of Set 12 | makakilo city
# Processing Record 31 of Set 12 | hovd
# Processing Record 32 of Set 12 | rio gallegos
# Processing Record 33 of Set 12 | axim
# Processing Record 34 of Set 12 | taoudenni
# Processing Record 35 of Set 12 | gulbarga
# Processing Record 36 of Set 12 | sampit
# Processing Record 37 of Set 12 | nevsehir
# Processing Record 38 of Set 12 | marrakesh
# Processing Record 39 of Set 12 | mount pleasant
# Processing Record 40 of Set 12 | tawzar
# City not found. Skipping...
# Processing Record 41 of Set 12 | komsomolskiy
# Processing Record 42 of Set 12 | dukat
# Processing Record 43 of Set 12 | afyonkarahisar
# Processing Record 44 of Set 12 | ust-tsilma
# Processing Record 45 of Set 12 | ghanzi
# Processing Record 46 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 47 of Set 12 | sept-iles
# Processing Record 48 of Set 12 | yining
# Processing Record 49 of Set 12 | san felipe
# Processing Record 50 of Set 12 | bac lieu
# Processing Record 1 of Set 13 | valenca
# Processing Record 2 of Set 13 | taksimo
# Processing Record 3 of Set 13 | takoradi
# Processing Record 4 of Set 13 | dingle
# Processing Record 5 of Set 13 | butembo
# Processing Record 6 of Set 13 | kapiri mposhi
# Processing Record 7 of Set 13 | runcu
# Processing Record 8 of Set 13 | yertsevo
# Processing Record 9 of Set 13 | brae
# Processing Record 10 of Set 13 | wilmington
# Processing Record 11 of Set 13 | ajdabiya
# Processing Record 12 of Set 13 | general pico
# Processing Record 13 of Set 13 | suclayin
# Processing Record 14 of Set 13 | virginia beach
# Processing Record 15 of Set 13 | truro
# Processing Record 16 of Set 13 | port-cartier
# Processing Record 17 of Set 13 | shibetsu
# Processing Record 18 of Set 13 | paamiut
# Processing Record 19 of Set 13 | manta
# Processing Record 20 of Set 13 | chimoio
# Processing Record 21 of Set 13 | lakeside
# Processing Record 22 of Set 13 | ahipara
# Processing Record 23 of Set 13 | yelovo
# Processing Record 24 of Set 13 | diu
# Processing Record 25 of Set 13 | abu jubayhah
# City not found. Skipping...
# Processing Record 26 of Set 13 | almaznyy
# Processing Record 27 of Set 13 | gardendale
# Processing Record 28 of Set 13 | guerande
# Processing Record 29 of Set 13 | presque isle
# Processing Record 30 of Set 13 | viedma
# Processing Record 31 of Set 13 | alpignano
# Processing Record 32 of Set 13 | panjab
# Processing Record 33 of Set 13 | metehara
# City not found. Skipping...
# Processing Record 34 of Set 13 | karpathos
# Processing Record 35 of Set 13 | liapades
# City not found. Skipping...
# Processing Record 36 of Set 13 | slonim
# Processing Record 37 of Set 13 | ewa beach
# Processing Record 38 of Set 13 | port augusta
# Processing Record 39 of Set 13 | zheleznodorozhnyy
# Processing Record 40 of Set 13 | siavonga
# Processing Record 41 of Set 13 | koumac
# Processing Record 42 of Set 13 | san andres
# Processing Record 43 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 44 of Set 13 | jacareacanga
# Processing Record 45 of Set 13 | klyuchi
# Processing Record 46 of Set 13 | dzerzhinskoye
# Processing Record 47 of Set 13 | broome
# Processing Record 48 of Set 13 | taunggyi
# Processing Record 49 of Set 13 | thornhill
# Processing Record 50 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 1 of Set 14 | sabzevar
# Processing Record 2 of Set 14 | izumo
# Processing Record 3 of Set 14 | yerbogachen
# Processing Record 4 of Set 14 | bayan
# Processing Record 5 of Set 14 | sandnessjoen
# Processing Record 6 of Set 14 | plerin
# Processing Record 7 of Set 14 | chimbote
# Processing Record 8 of Set 14 | wabash
# Processing Record 9 of Set 14 | mahanje
# Processing Record 10 of Set 14 | asau
# Processing Record 11 of Set 14 | liverpool
# Processing Record 12 of Set 14 | kamenka
# Processing Record 13 of Set 14 | kloulklubed
# Processing Record 14 of Set 14 | ust-nera
# Processing Record 15 of Set 14 | buariki
# City not found. Skipping...
# Processing Record 16 of Set 14 | carballo
# Processing Record 17 of Set 14 | kailua
# Processing Record 18 of Set 14 | high level
# Processing Record 19 of Set 14 | zheshart
# Processing Record 20 of Set 14 | balkhash
# Processing Record 21 of Set 14 | tara
# Processing Record 22 of Set 14 | correntina
# Processing Record 23 of Set 14 | zachagansk
# City not found. Skipping...
# Processing Record 24 of Set 14 | okhotsk
# Processing Record 25 of Set 14 | jadu
# Processing Record 26 of Set 14 | maine-soroa
# Processing Record 27 of Set 14 | livingston
# Processing Record 28 of Set 14 | nainpur
# Processing Record 29 of Set 14 | antipovka
# Processing Record 30 of Set 14 | dickinson
# Processing Record 31 of Set 14 | quang ngai
# Processing Record 32 of Set 14 | yelan-koleno
# Processing Record 33 of Set 14 | kavaratti
# Processing Record 34 of Set 14 | ankazoabo
# Processing Record 35 of Set 14 | darnah
# Processing Record 36 of Set 14 | christchurch
# Processing Record 37 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 38 of Set 14 | kandla
# Processing Record 39 of Set 14 | toyooka
# Processing Record 40 of Set 14 | aksarka
# Processing Record 41 of Set 14 | harpalpur
# Processing Record 42 of Set 14 | port hedland
# Processing Record 43 of Set 14 | luba
# Processing Record 44 of Set 14 | tunduru
# City not found. Skipping...
# Processing Record 45 of Set 14 | jizan
# Processing Record 46 of Set 14 | orange
# Processing Record 47 of Set 14 | chapais
# Processing Record 48 of Set 14 | flinders
# Processing Record 49 of Set 14 | comodoro rivadavia
# Processing Record 50 of Set 14 | houma
# Processing Record 1 of Set 15 | indramayu
# Processing Record 2 of Set 15 | surgana
# Processing Record 3 of Set 15 | toamasina
# Processing Record 4 of Set 15 | sorokino
# Processing Record 5 of Set 15 | charleville-mezieres
# Processing Record 6 of Set 15 | itamaraju
# Processing Record 7 of Set 15 | kysyl-syr
# Processing Record 8 of Set 15 | iquitos
# Processing Record 9 of Set 15 | kiunga
# Processing Record 10 of Set 15 | labytnangi
# Processing Record 11 of Set 15 | mocambique
# City not found. Skipping...
# Processing Record 12 of Set 15 | vrangel
# Processing Record 13 of Set 15 | saint george
# Processing Record 14 of Set 15 | abnub
# Processing Record 15 of Set 15 | krasne
# Processing Record 16 of Set 15 | sidi qasim
# City not found. Skipping...
# Processing Record 17 of Set 15 | salto
# Processing Record 18 of Set 15 | clarence town
# Processing Record 19 of Set 15 | kenitra
# Processing Record 20 of Set 15 | pecos
# Processing Record 21 of Set 15 | nuristan
# Processing Record 22 of Set 15 | magadan
# Processing Record 23 of Set 15 | kolondieba
# Processing Record 24 of Set 15 | liepaja
# Processing Record 25 of Set 15 | inverell
# Processing Record 26 of Set 15 | shelburne
# Processing Record 27 of Set 15 | villazon
# Processing Record 28 of Set 15 | pontian kecil
# Processing Record 29 of Set 15 | obregon
# Processing Record 30 of Set 15 | qeshm
# Processing Record 31 of Set 15 | ganzhou
# Processing Record 32 of Set 15 | aksu
# Processing Record 33 of Set 15 | esna
# Processing Record 34 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 35 of Set 15 | menongue
# Processing Record 36 of Set 15 | ararat
# Processing Record 37 of Set 15 | bonavista
# Processing Record 38 of Set 15 | yaransk
# Processing Record 39 of Set 15 | inderborskiy
# City not found. Skipping...
# Processing Record 40 of Set 15 | lahat
# Processing Record 41 of Set 15 | morant bay
# Processing Record 42 of Set 15 | nalut
# Processing Record 43 of Set 15 | abong mbang
# Processing Record 44 of Set 15 | pucallpa
# Processing Record 45 of Set 15 | hay river
# Processing Record 46 of Set 15 | abu dhabi
# Processing Record 47 of Set 15 | candolim
# Processing Record 48 of Set 15 | darlawn
# Processing Record 49 of Set 15 | fort nelson
# Processing Record 50 of Set 15 | manggar
# Processing Record 1 of Set 16 | matara
# Processing Record 2 of Set 16 | antalaha
# Processing Record 3 of Set 16 | tual
# Processing Record 4 of Set 16 | naudero
# Processing Record 5 of Set 16 | sorland
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 698

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Dikson      RU  73.5069   80.5464     -8.54        98         100
# 1        Buraydah      SA  26.3260   43.9750     81.05        19          92
# 2  Saint-Philippe      RE -21.3585   55.7679     81.99        91         100
# 3    Punta Arenas      CL -53.1500  -70.9167     53.71        50          75
# 4          Shingu      JP  33.7333  135.9833     44.31        51           0
# 5       Busselton      AU -33.6500  115.3333     57.96        77           0
# 6          Barrow      US  71.2906 -156.7887     15.82        86         100
# 7           Genhe      CN  50.7833  121.5167     -0.09       100         100
# 8       Upernavik      GL  72.7868  -56.1549     21.20        82          50
# 9    Puerto Ayora      EC  -0.7393  -90.3518     82.54        82          51
#
#    Wind Speed Current Description
# 0        7.61     overcast clouds
# 1        6.58     overcast clouds
# 2        9.71          light rain
# 3       21.85       broken clouds
# 4        6.67           clear sky
# 5       12.95           clear sky
# 6       13.80     overcast clouds
# 7        2.04     overcast clouds
# 8        1.83    scattered clouds
# 9        1.99       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE

# Recreate the DataFrame by using the new column order
# YOUR CODE HERE

# Display sample data
# YOUR CODE HERE

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = 'WeatherPy_Database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label='City_ID')
